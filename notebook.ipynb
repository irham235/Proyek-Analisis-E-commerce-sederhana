# %% [markdown]
# # Proyek Analisis Data: Nama dataset
# - Nama: Irham Maulana
# - Email: irhammaulana235@gmail.com
# - Id Dicoding: irham235

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Kategori produk apa yang paling banyak dan paling sedikit dipesan
# - Payment apa yang sering digunakan pelanggan
# - Bagaimana demografi pelanggan yang kita miliki
# - Kapan terakhir pelanggan melakukan transaksi
# - Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir ?
# - Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir

# %% [markdown]
# ## Menyaipkan semua library yang dibuthkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# Mount drive untuk bisa membaca file bertipe csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Memuat tabel customers

# %%
customers_df = pd.read_csv("/content/drive/MyDrive/proyek analisis data/data/customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# Memuat tabel orders

# %%
orders_df = pd.read_csv("/content/drive/MyDrive/proyek analisis data/data/orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# Memuat tabel product

# %%
product_df = pd.read_csv("/content/drive/MyDrive/proyek analisis data/data/products_dataset.csv")
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# Memuat tabel payment

# %%
payment_df = pd.read_csv("/content/drive/MyDrive/proyek analisis data/data/order_payments_dataset.csv")
payment_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Menilai tabel customers_df

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
print("Jumlah duplikasi:", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi: 0

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# Menilai tabel orders_df

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print("Jumlah duplikasi:", orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi: 0

# %%
orders_df.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# Menilai tabel product_df

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
product_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
print("Jumlah duplikasi: ", product_df.duplicated().sum())

product_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# Menilai tabel payment_df

# %%
payment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
print("Jumnlah duplikasi: ", payment_df.duplicated().sum())
payment_df.describe()
# Out:
# Jumnlah duplikasi:  0
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# **Membersihkan tabel orders_df**

# %% [markdown]
# Missing value

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %% [markdown]
# Menggunakan tanggal setelahnya untuk mengisi nilai yang hilang

# %%
orders_df['order_approved_at'].fillna(method='bfill', inplace=True)

# %%
orders_df['order_delivered_carrier_date'].fillna(method='bfill', inplace=True)

# %%
orders_df['order_delivered_customer_date'].fillna(method='bfill', inplace=True)

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# Mengganti tipe data

# %%
datetime_columns = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99441 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   99441 non-null  datetime64[ns]
#  6   order_delivered_customer_date  99441 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# **Membersihkan tabel product_df**

# %% [markdown]
# Missing value

# %%
product_df[product_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
product_df.product_category_name.value_counts()
# Out:
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_category_name, Length: 73, dtype: int64

# %%
# menggunakan nilai yang paling dominan
product_df['product_category_name'].fillna(value="cama_mesa_banho", inplace=True)

# %%
# menggunakan nilai rata"
product_df.product_name_lenght.fillna(value=product_df.product_name_lenght.mean(), inplace=True)
product_df.product_description_lenght.fillna(value=product_df.product_description_lenght.mean(), inplace=True)
product_df.product_photos_qty.fillna(value=product_df.product_photos_qty.mean(), inplace=True)
product_df.product_weight_g.fillna(value=product_df.product_weight_g.mean(), inplace=True)
product_df.product_length_cm.fillna(value=product_df.product_length_cm.mean(), inplace=True)
product_df.product_height_cm.fillna(value=product_df.product_height_cm.mean(), inplace=True)
product_df.product_width_cm.fillna(value=product_df.product_width_cm.mean(), inplace=True)

# %%
product_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# Mengubah Tipe Data

# %%
integer_columns = ["product_name_lenght", "product_description_lenght", "product_photos_qty"]

for column in integer_columns:
  product_df[column] = pd.to_numeric(product_df[column])

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32951 non-null  object
#  2   product_name_lenght         32951 non-null  float64
#  3   product_description_lenght  32951 non-null  float64
#  4   product_photos_qty          32951 non-null  float64
#  5   product_weight_g            32951 non-null  float64
#  6   product_length_cm           32951 non-null  float64
#  7   product_height_cm           32951 non-null  float64
#  8   product_width_cm            32951 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# Terdapat innacurate dibagian min product_weight_g

# %% [markdown]
# sebenarnya saya bingung, karena ada beberapa produk yg tidak memiliki berat, contohnya voucher, tetapi disini saya akan membuat batas min adalah 1 g

# %%
product_df.product_weight_g.replace(product_df.product_weight_g.min(), 1, inplace=True)

# %%
product_df.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32951.000000                32951.000000        32951.000000
# mean             48.476949                  771.495285            2.188986
# std              10.150458                  629.208849            1.720614
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  344.000000            1.000000
# 50%              51.000000                  604.000000            1.000000
# 75%              57.000000                  961.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32951.000000       32951.000000       32951.000000
# mean        2276.472609          30.815078          16.937661
# std         4281.908709          16.913945          13.637140
# ...

# %% [markdown]
# **Membersihkan tabel payment_df**

# %%
payment_df.payment_type.value_counts()
# Out:
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: payment_type, dtype: int64

# %% [markdown]
# seperti yang terlihat di atas ada tipe pembayaran yang not_defined

# %%
# mengambil nilai yang sering muncul yaitu credit_card
payment_df.loc[payment_df['payment_type'] == 'not_defined', 'payment_type'] ='credit_card'

# %% [markdown]
# coba cek kembali

# %%
payment_df.payment_type.value_counts()
# Out:
# credit_card    76798
# boleto         19784
# voucher         5775
# debit_card      1529
# Name: payment_type, dtype: int64

# %% [markdown]
# Karena tabel customers_df tidak ada missing value, duplikasi data, tipe data yang tidak sesuai. Maka dilanjutkan ke tahap selanjutnya

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explorasi data customers_df

# %% [markdown]
# melihat rangkuman parameter statistik dari data customers_df menggunakan method describe

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# Melihat persebaran jumlah pelanggan berdasarkan city

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False).reset_index()
# Out:
#        customer_city  customer_id
# 0          sao paulo        15540
# 1     rio de janeiro         6882
# 2     belo horizonte         2773
# 3           brasilia         2131
# 4           curitiba         1521
# ...              ...          ...
# 4114          ibiara            1
# 4115      rio espera            1
# 4116  rio dos indios            1
# 4117  rio dos cedros            1
# 4118          lagoao            1
#
# [4119 rows x 2 columns]

# %% [markdown]
# Melihat persebaran jumlah pelanggan berdasarkan state

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False).reset_index()
# Out:
#    customer_state  customer_id
# 0              SP        41746
# 1              RJ        12852
# 2              MG        11635
# 3              RS         5466
# 4              PR         5045
# 5              SC         3637
# 6              BA         3380
# 7              DF         2140
# 8              ES         2033
# 9              GO         2020
# 10             PE         1652
# 11             CE         1336
# 12             PA          975
# 13             MT          907
# 14             MA          747
# 15             MS          715
# 16             PB          536
# 17             PI          495
# 18             RN          485
# 19             AL          413
# 20             SE          350
# 21             TO          280
# 22             RO          253
# 23             AM          148
# 24             AC           81
# 25             AP           68
# 26             RR           46

# %% [markdown]
# ### Explorasi data orders_df

# %%
orders_df.describe(include="all")
# Out:
# <ipython-input-41-903538279252>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders_df.describe(include="all")
# <ipython-input-41-903538279252>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders_df.describe(include="all")
# <ipython-input-41-903538279252>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   orders_df.describe(include="all")
# ...

# %% [markdown]
# melihat order_status

# %%
orders_df.groupby(by="order_status").customer_id.nunique().sort_values(ascending=False)
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Explorasi data orders_df dan customers_df

# %% [markdown]
# membuat sebuah kolom baru bernama status

# %%
customer__unique_id_in_customers_df = customers_df.customer_unique_id.tolist()
customers_df["status"] = customers_df["customer_unique_id"].apply(lambda x: "Active" if x in customer__unique_id_in_customers_df else "Non Active")
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 6967   f32ab95a50b915c9ae8036374fe02e21  abfe742e782fb10f5c824fcb849e5cd1
# 16481  44d8a794c8e40d5063528003d8974881  2a1ffd99dbed9fffa55c9fd6a31f799b
# 93060  aa1922a8ba370a11a86c1ad869c9f370  6b44ef4c4a50d85e5f74552882776352
# 32494  319bc74aa0d3a68dc4d3a98b9fecb45c  261bc8d67bf6264cb8352c0700e98f3f
# 97415  fe8854b59888e2f4e16fa95a9fde3e27  70385f2723b5983e2102dd4b06a266eb
#
#        customer_zip_code_prefix      customer_city customer_state  status
# 6967                      18071           sorocaba             SP  Active
# 16481                      2020          sao paulo             SP  Active
# 93060                     13301                itu             SP  Active
# 32494                     63040  juazeiro do norte             CE  Active
# 97415                     96010            pelotas             RS  Active

# %% [markdown]
# memperoleh informasi terkait jumlah pelanggan yang berstatus "Active" dan "Non Active"

# %%
customers_df.groupby(by="status").customer_unique_id.count()
# Out:
# status
# Active    99441
# Name: customer_unique_id, dtype: int64

# %% [markdown]
# Melakukan merge

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# Jumlah order berdasarkan city

# %%
orders_customers_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#            customer_city  order_id
# 0              sao paulo     15540
# 1         rio de janeiro      6882
# 2         belo horizonte      2773
# 3               brasilia      2131
# 4               curitiba      1521
# 5               campinas      1444
# 6           porto alegre      1379
# 7               salvador      1245
# 8              guarulhos      1189
# 9  sao bernardo do campo       938

# %% [markdown]
# Jumlah order berdasarkan state

# %%
orders_customers_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#   customer_state  order_id
# 0             SP     41746
# 1             RJ     12852
# 2             MG     11635
# 3             RS      5466
# 4             PR      5045
# 5             SC      3637
# 6             BA      3380
# 7             DF      2140
# 8             ES      2033
# 9             GO      2020

# %% [markdown]
# ### Eksplorasi data product_df

# %%
product_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32951                 32951
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3639
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32951.000000                32951.000000        32951.000000
# ...

# %%
product_df.groupby(by="product_category_name").product_weight_g.nunique().sort_values(ascending=False)
# Out:
# product_category_name
# esporte_lazer                    613
# cama_mesa_banho                  579
# utilidades_domesticas            504
# beleza_saude                     462
# brinquedos                       443
#                                 ...
# casa_conforto_2                    5
# fashion_roupa_infanto_juvenil      5
# pc_gamer                           3
# seguros_e_servicos                 2
# cds_dvds_musicais                  1
# Name: product_weight_g, Length: 73, dtype: int64

# %% [markdown]
# ### Eksplorasi payment_df

# %%
payment_df.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            4
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76798
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# Metode pembayaran yang pelanggan gunakan

# %%
payment_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76508
# boleto         19784
# voucher         3866
# debit_card      1528
# Name: order_id, dtype: int64

# %% [markdown]
# Melihat nilai pembayaran yang di keluarkan dari beberapa payment_type

# %%
payment_df.groupby(by="payment_type").payment_value.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    25500
# boleto         10541
# voucher         3539
# debit_card      1383
# Name: payment_value, dtype: int64

# %% [markdown]
# ### Eksplorasi product_df dan payment_df

# %% [markdown]
# menyalin order_id ke product_df agar proses merge tidak error

# %%
product_df['order_id'] = payment_df['order_id']

# %% [markdown]
# proses merge

# %%
product_payment_df = pd.merge(
    left=payment_df,
    right=product_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
product_payment_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value                        product_id  \
# 0                     8          99.33  1e9e8ef04dbcff4541ed26657ea517e5
# 1                     1          24.39  3aa071139cb16b67ca9e5dea641aaa2f
# 2                     1          65.71  96bd76ec8810374ed1b65e291975717f
# 3                     8         107.78  cef67bcfe19066a932b7673e239eb23d
# 4                     2         128.45  9dc1a7de274444849c219cff195d0b71
#
#    product_category_name  product_name_lenght  product_description_lenght  \
# ...

# %% [markdown]
# Melihat informasi nilai pembayaran berdasarkan payment type

# %%
product_payment_df.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#               order_id  payment_value
# payment_type
# credit_card      76508    12568794.40
# boleto           19784     2869361.27
# voucher           3866      447378.46
# debit_card        1528      217989.79

# %%
product_payment_df.groupby(by="product_category_name").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_value
# product_category_name
# cama_mesa_banho                    3633      586388.35
# esporte_lazer                      2863      466053.34
# moveis_decoracao                   2654      426316.28
# beleza_saude                       2440      400679.41
# utilidades_domesticas              2329      377805.79
# ...                                 ...            ...
# pc_gamer                              3         557.77
# fashion_roupa_infanto_juvenil         5         512.71
# casa_conforto_2                       5         410.65
# seguros_e_servicos                    2         223.08
# cds_dvds_musicais                     1          85.83
#
# [73 rows x 2 columns]

# %% [markdown]
# ### Eksplorasi Data all_df

# %% [markdown]
# melakukan merge

# %%
all_df = pd.merge(
    left=product_payment_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id",
)
all_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value                        product_id  \
# 0                     8          99.33  1e9e8ef04dbcff4541ed26657ea517e5
# 1                     1          24.39  3aa071139cb16b67ca9e5dea641aaa2f
# 2                     1          65.71  96bd76ec8810374ed1b65e291975717f
# 3                     8         107.78  cef67bcfe19066a932b7673e239eb23d
# 4                     2         128.45  9dc1a7de274444849c219cff195d0b71
#
#    product_category_name  product_name_lenght  product_description_lenght  \
# ...

# %% [markdown]
# Melihat preferensi pembelian berdasarkan city dan payment type

# %%
all_df.groupby(by=["customer_state", "payment_type"]).agg({
    "payment_value": "sum"
})
# Out:
#                              payment_value
# customer_state payment_type
# AC             boleto              3908.46
#                credit_card        14625.41
#                debit_card           349.62
#                voucher              902.27
# AL             boleto             13742.62
# ...                                    ...
# SP             voucher           175566.81
# TO             boleto             13287.28
#                credit_card        46365.77
#                debit_card           896.65
#                voucher             4068.89
#
# [105 rows x 1 columns]

# %%
all_df.groupby(by=["customer_state", "product_category_name"]).agg({
    "order_id": "nunique",
    "payment_value": "sum"
})
# Out:
#                                         order_id  payment_value
# customer_state product_category_name
# AC             automotivo                      1          88.27
#                bebes                           3        1221.85
#                beleza_saude                    6        1542.54
#                brinquedos                      1         139.53
#                cama_mesa_banho                 5        1045.84
# ...                                          ...            ...
# TO             perfumaria                      2         227.10
#                relogios_presentes              4         935.83
#                sinalizacao_e_seguranca         1          45.63
#                telefonia                       4         701.93
#                utilidades_domesticas           4         707.28
#
# [1141 rows x 2 columns]

# %% [markdown]
# Melihat informasi order berdasarkan state

# %%
all_df.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 41745     6033831.48
# RJ                 12852     2157760.01
# MG                 11635     1881519.11
# RS                  5466      896870.13
# PR                  5045      815072.48
# SC                  3637      625804.09
# BA                  3380      619566.29
# DF                  2140      355532.08
# GO                  2020      352423.70
# ES                  2033      326720.17
# PE                  1652      325759.20
# CE                  1336      280412.48
# PA                   975      218556.53
# MT                   907      191534.04
# MA                   747      153025.80
# PB                   536      142662.01
# MS                   715      138939.08
# PI                   495      108950.05
# RN                   485      105848.68
# AL                   413       97827.08
# SE                   350       75246.25
# TO                   280       64618.59
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Kategori produk apa yang paling banyak dan paling sedikit di pesan ?

# %% [markdown]
# membuat dataframe baru untuk menampung informasi terkait jumlah order tiap kategori

# %%
sum_orders_category_df = all_df.groupby("product_category_name").order_id.nunique().sort_values(ascending=False).reset_index()
sum_orders_category_df.head(15)
# Out:
#           product_category_name  order_id
# 0               cama_mesa_banho      3633
# 1                 esporte_lazer      2863
# 2              moveis_decoracao      2654
# 3                  beleza_saude      2440
# 4         utilidades_domesticas      2329
# 5                    automotivo      1897
# 6        informatica_acessorios      1635
# 7                    brinquedos      1410
# 8            relogios_presentes      1326
# 9                     telefonia      1133
# 10                        bebes       919
# 11                   perfumaria       868
# 12  fashion_bolsas_e_acessorios       848
# 13                    papelaria       847
# 14                   cool_stuff       789

# %% [markdown]
# menggunakan function subplot

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="order_id", y="product_category_name", data=sum_orders_category_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Category", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="order_id", y="product_category_name", data=sum_orders_category_df.sort_values(by="order_id", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Category", loc="center", fontsize=15)
ax[1].tick_params(axis ='y', labelsize=12)

plt.suptitle("Best and Worst Performing Category by Number of Orders", fontsize=20)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Payment apa yang paling sering digunakan

# %% [markdown]
# membuat dataframe baru

# %%
bypayment_df = all_df.groupby(by="payment_type").customer_id.nunique().reset_index()
bypayment_df.rename(columns={
    "customer_id": "customer_count",
    "payment_type": "payment",
}, inplace=True)
bypayment_df
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    x="payment",
    y="customer_count",
    data=bypayment_df.sort_values(by="customer_count", ascending=False),
    palette=colors_
)
plt.title("Jumlah pelanggan yang menggunakan beberapa metode pembayaran", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %% [markdown]
# ### Pertanyaan 3: Bagaimana demografi pelanggan berdasarkan state

# %%
bystate_df = all_df.groupby(by="customer_state").customer_id.nunique().reset_index()
bystate_df.rename(columns={
    "customer_id": "customer_count",
    "customer_state": "state",
}, inplace=True)
bystate_df
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    y="customer_count",
    x="state",
    data=bystate_df.sort_values(by="customer_count", ascending=False),
    palette=colors_
)
plt.title("Jumlah pelanggan berdasarkan States ", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()

# %% [markdown]
# ### Menggunakan metode RFM untuk pertanyaan 4-6

# %% [markdown]
# **Pertanyaan 4: Kapan terakhir pelanggan melakukan transaksi**

# %% [markdown]
# **Pertanyaan 5: Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir ?**

# %% [markdown]
# **Pertanyaan 6: Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir**

# %% [markdown]
# membuat dataframe baru untuk menampung 3 parameter yaitu recency, frequency, dan monetary

# %%
rfm_df = all_df.groupby(by="customer_id", as_index=False).agg({
    "order_purchase_timestamp": "max", # mengambil tanggal order terakhir
    "order_id": "nunique", # menghitung jumlah order
    "payment_value": "sum" # menghitung jumlah revenue yang dihasilkan
})
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]

# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = orders_df["order_purchase_timestamp"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)

rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#                         customer_id  frequency  monetary  recency
# 0  00012a2ce6f8dcda20d059ce98491703          1    114.74      337
# 1  000161a058600d5901f007fab4c27140          1     67.41      458
# 2  0001fd6190edaaf884bcaf3d49edf079          1    195.42      596
# 3  0002414f95344307404f0ace7a26f1d5          1    179.35      427
# 4  000379cdec625522490c315e70c7a9fb          1    107.01      198

# %% [markdown]
# mengidentifikasi best customer berdasarkan parameter frequency, monetary, dan recancy

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=10, rotation=300)

sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis ='x', labelsize=10, rotation=300)

sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis ='x', labelsize=10, rotation=300)

plt.suptitle("Best Customer Based on RFM Parameters (payment_type)", fontsize=20)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1: Pada visualisasi data dapat dilihat bahwa kategori produk yang paling sering dipesan adalah cama_mesa_banho, dan kategori produk yang paling jarang dipesan adalah cds_dvds_musicals
# - Conclution pertanyaan 2: Dari visualisasi data yang didapat dapat disimpulkan bahwa banyak customer yang menggunakan metode pembayaran credit card
# - Conclution pertanyaan 3: Dari visualisasi data yang didapat, bahwa persebaran pelanggan terbanyak terdapat di negara bagian SP, dan yang paling sedikit adalah negara bagian RR

# %% [markdown]
# ### Pengen di masukin datanya tapi masih bingung bagian date_time agar orderan dari tahun 2016-2018 grafiknya tidak menyatu

# %% [markdown]
# masih ke kurangan informasi bagaimana cara nya, maka dari itu saya tidak masukkan

# %%
monthly_orders_df = all_df.resample(rule='M', on='order_purchase_timestamp').agg({
    "order_id": "nunique",
    "payment_value": "sum"
})
monthly_orders_df.index = monthly_orders_df.index.strftime('%Y-%m')
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "payment_value": "revenue"
}, inplace=True)
monthly_orders_df.head()
# Out:
#   order_purchase_timestamp  order_count    revenue
# 0                  2016-09            3     252.24
# 1                  2016-10          324   59363.30
# 2                  2016-11            0       0.00
# 3                  2016-12            1      19.62
# 4                  2017-01          800  140904.13

# %%
filtered_df = all_df[(all_df['order_purchase_timestamp'] >= '2017-01-01') & (all_df['order_purchase_timestamp'] <= '2017-12-31')]
monthly_orders_df = filtered_df.resample(rule='M', on='order_purchase_timestamp').agg({
    "order_id": "nunique",
    "payment_value": "sum"
})
monthly_orders_df.index = monthly_orders_df.index.strftime('%B') #mengubah format date menjadi nama bulan

monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "payment_value": "revenue"
}, inplace=True)

plt.figure(figsize=(10, 5))
plt.plot(monthly_orders_df["order_purchase_timestamp"], monthly_orders_df["order_count"], marker='o', linewidth=2, color="#72BCD4")
plt.title("Number of Orders per Month (2017)", loc="center", fontsize=20)
plt.xticks(fontsize=8)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### Menyimpan berkas data yang sudah dibersihkan

# %%
all_df.to_csv("all_data.csv", index=False)
